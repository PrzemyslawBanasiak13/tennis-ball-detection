# %% [markdown]
# # Data Exploration Notebook
# This notebook contains initial data exploration and visualisation.

# %%
import helper_functions

# %% [markdown]
# ## Check image info

# %%
train_path = '../data/external/emptyballs/train'
test_path = '../data/external/emptyballs/test'

# %%
# print information about first images in `train/ball` localisation

print("Basic image info:")
for i in range(3):
    print("\n------------------------------------------------------------")
    print(f"Image {i+1}:")
    helper_functions.print_image_info(f"{train_path}/balls/ball{i}.jpg")
# Out:
# Basic image info:
#
# ------------------------------------------------------------
# Image 1:
# Filename                 : ../data/external/emptyballs/train/balls/ball0.jpg
# Image Size               : (640, 480)
# Image Height             : 480
# Image Width              : 640
# Image Format             : JPEG
# Image Mode               : RGB
# Image is Animated        : False
# Frames in Image          : 1
#
# ------------------------------------------------------------
# Image 2:
# Filename                 : ../data/external/emptyballs/train/balls/ball1.jpg
# Image Size               : (640, 480)
# Image Height             : 480
# Image Width              : 640
# Image Format             : JPEG
# Image Mode               : RGB
# Image is Animated        : False
# Frames in Image          : 1
#
# ------------------------------------------------------------
# Image 3:
# Filename                 : ../data/external/emptyballs/train/balls/ball2.jpg
# ...

# %%
# print information about first images in `train/empty` localisation

print("Basic image info:")
for i in range(3):
    print("\n------------------------------------------------------------")
    print(f"Image {i+1}:")
    helper_functions.print_image_info(f"{train_path}/empty/empty{i}.jpg")
# Out:
# Basic image info:
#
# ------------------------------------------------------------
# Image 1:
# Filename                 : ../data/external/emptyballs/train/empty/empty0.jpg
# Image Size               : (640, 480)
# Image Height             : 480
# Image Width              : 640
# Image Format             : JPEG
# Image Mode               : RGB
# Image is Animated        : False
# Frames in Image          : 1
#
# ------------------------------------------------------------
# Image 2:
# Filename                 : ../data/external/emptyballs/train/empty/empty1.jpg
# Image Size               : (640, 480)
# Image Height             : 480
# Image Width              : 640
# Image Format             : JPEG
# Image Mode               : RGB
# Image is Animated        : False
# Frames in Image          : 1
#
# ------------------------------------------------------------
# Image 3:
# Filename                 : ../data/external/emptyballs/train/empty/empty2.jpg
# ...

# %% [markdown]
# So it turns out that those are raw `.jpg` images without labelling neccesary for object detection. Data would need further improvements to succesfully use it during model building and training process.
#
# > Useful image preprocessing tool for object detection models:
# > [LabelImg](https://github.com/heartexlabs/labelImg)

# %% [markdown]
# ## Preview

# %%
helper_functions.plot_images(f"{train_path}/balls")

# %%
helper_functions.plot_images(f"{train_path}/empty")
